# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset,TensorDataset
from autoencoder import Autoencoder
import torchvision
from model2 import classification_model
import copy
import partition
from pca import PCADigitReducer
from autoencoder import reduce_dimensions
from training import train,test
from federated_learning import distribute_global_model, federated_averaging

# %% [markdown]
# # Initialization

# %%
# Predefined stuff

n_epochs = 3
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
# training and testing data as dataloaders

train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('/files/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('/files/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)

# %%
print((train_loader.dataset))
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /files/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
# get their respective data

train_loader_pca = copy.copy(train_loader)
test_loader_pca = copy.copy(test_loader)

train_loader_auto = copy.copy(train_loader)
test_loader_auto = copy.copy(test_loader)

# %%
# PCA DR, later encapsulate this shit
class CustomTensorDataset(TensorDataset):
    def __init__(self, *tensors):
        super().__init__(*tensors)
        self.data = tensors[0]
        self.targets = tensors[1] 


train_data = []
train_labels = []
for data, labels in train_loader_pca:
    train_data.append(data.view(data.size(0), -1))  
    train_labels.append(labels)
train_data = torch.cat(train_data, dim=0)  
train_labels = torch.cat(train_labels, dim=0)

train_data_np = train_data.numpy()

pca = PCADigitReducer(100)
train_data_reduced = pca.fit_transform(train_data_np)  

train_data_reconstructed_np = pca.inverse_transform(train_data_reduced) 
train_data_reconstructed = torch.tensor(train_data_reconstructed_np, dtype=torch.float32)

train_data_reconstructed = train_data_reconstructed.view(-1, 1, 28, 28)

train_data_reconstructed = (train_data_reconstructed - 0.1307) / 0.3081

batch_size_train = train_loader_pca.batch_size
train_dataset_pca = CustomTensorDataset(train_data_reconstructed, train_labels)
train_loader_reduced_pca = DataLoader(train_dataset_pca, batch_size=batch_size_train, shuffle=True)

# %%
trainingset_pca = train_loader_reduced_pca.dataset

print(trainingset_pca.targets)
# Out:
# tensor([4, 8, 8,  ..., 7, 0, 8])

# %%
# Autoencoder initialization, does take time because the Autoencoder has to be trained first. Later maybe store the parameters.
latent_dim = 100  
autoencoder = Autoencoder(latent_dim=latent_dim)
auto_criterion = nn.MSELoss()
auto_optimizer = optim.Adam(autoencoder.parameters(), lr=1e-3)
auto_num_epochs = 5
for epoch in range(auto_num_epochs): 
    for images, _ in train_loader_auto:
        auto_optimizer.zero_grad()
        reconstructed = autoencoder(images)
        loss = auto_criterion(reconstructed, images)  
        loss.backward()
        auto_optimizer.step()
        
    print(f"Epoch [{epoch+1}/5], Loss: {loss.item()}")
# Out:
# Epoch [1/5], Loss: 0.5411480665206909
# Epoch [2/5], Loss: 0.5199205279350281
# Epoch [3/5], Loss: 0.4910971224308014
# Epoch [4/5], Loss: 0.519383430480957
# Epoch [5/5], Loss: 0.5129168033599854

# %%
autoencoder.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
latent_features, labels = reduce_dimensions(train_loader_auto, autoencoder.encoder, device)
latent_features = latent_features.detach()

reconstructed_images = autoencoder.decoder(latent_features.to(device))  
reconstructed_images = reconstructed_images.view(-1, 1, 28, 28)  # Reshape to [batch_size, channels, height, width]

reconstructed_dataset = CustomTensorDataset(reconstructed_images.cpu(), labels)  
reduced_train_loader_auto = DataLoader(reconstructed_dataset, batch_size=batch_size_train, shuffle=True)

# %%
# Experiment for multiple alphas
alpha_values = [0.005, 0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1]
results = {"classic": {}, "pca": {}, "autoencoder": {}}

for alpha in alpha_values:
    print(f"\nRunning experiment for alpha = {alpha}\n")

    # Partition datasets for each method
    partitioned_data_classic = partition.balanced_dirichlet_partition(
        train_loader.dataset, partitions_number=4, alpha=alpha)
    classic_client_loaders = [
        DataLoader(Subset(train_loader.dataset, indices), batch_size=batch_size_train, shuffle=True)
        for indices in partitioned_data_classic.values()
    ]

    partitioned_data_pca = partition.balanced_dirichlet_partition(
        train_loader_reduced_pca.dataset, partitions_number=4, alpha=alpha)
    pca_client_loaders = [
        DataLoader(Subset(train_loader_reduced_pca.dataset, indices), batch_size=batch_size_train, shuffle=True)
        for indices in partitioned_data_pca.values()
    ]

    partitioned_data_auto = partition.balanced_dirichlet_partition(
        reduced_train_loader_auto.dataset, partitions_number=4, alpha=alpha)
    auto_client_loaders = [
        DataLoader(Subset(reduced_train_loader_auto.dataset, indices), batch_size=batch_size_train, shuffle=True)
        for indices in partitioned_data_auto.values()
    ]

    if (alpha == 0.005) : 
        for i in range(len(pca_client_loaders[0].dataset)):
            sample, label = pca_client_loaders[0].dataset[i]
            print(f"Sample {i} shape: {sample.shape}, Label: {label}")
    

    # Federated learning for classic
    gloabl_model_classic = classification_model()
    local_models_classic = [copy.deepcopy(gloabl_model_classic) for _ in range(4)]
    test_losses_classic, test_accuracies_classic = [], []
    for round_idx in range(4):
        local_weights_classic = []
        for client_idx, client_model in enumerate(local_models_classic):
            optimizer = optim.SGD(client_model.parameters(), lr=learning_rate, momentum=momentum)
            for epoch in range(1, n_epochs + 1):
                train(epoch, client_model, classic_client_loaders[client_idx], optimizer, log_interval, [], [])
            client_weights = [param.data.numpy() for param in client_model.parameters()]
            local_weights_classic.append(client_weights)
        global_weights_classic = federated_averaging(local_weights_classic)
        distribute_global_model(global_weights_classic, local_models_classic, single=False)
        distribute_global_model(global_weights_classic, gloabl_model_classic, single=True)
    test(gloabl_model_classic, test_loader, test_losses_classic)
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = gloabl_model_classic(data)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum().item()
    accuracy = 100. * correct / len(test_loader.dataset)
    test_accuracies_classic.append(accuracy)
    results["classic"][alpha] = {"losses": test_losses_classic, "accuracy": test_accuracies_classic}

    # Federated learning for PCA
    global_model_pca = classification_model()
    local_models_pca = [copy.deepcopy(global_model_pca) for _ in range(4)]
    test_losses_pca, test_accuracies_pca = [], []
    for round_idx in range(4):
        local_weights_pca = []
        for client_idx, client_model in enumerate(local_models_pca):
            optimizer = optim.SGD(client_model.parameters(), lr=learning_rate, momentum=momentum)
            for epoch in range(1, n_epochs + 1):
                train(epoch, client_model, pca_client_loaders[client_idx], optimizer, log_interval, [], [])
            client_weights = [param.data.numpy() for param in client_model.parameters()]
            local_weights_pca.append(client_weights)
        global_weights_pca = federated_averaging(local_weights_pca)
        distribute_global_model(global_weights_pca, local_models_pca, single=False)
        distribute_global_model(global_weights_pca, global_model_pca, single=True)
    test(global_model_pca, test_loader_pca, test_losses_pca)
    correct = 0
    with torch.no_grad():
        for data, target in test_loader_pca:
            output = global_model_pca(data)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum().item()
    accuracy = 100. * correct / len(test_loader_pca.dataset)
    test_accuracies_pca.append(accuracy)
    results["pca"][alpha] = {"losses": test_losses_pca, "accuracy": test_accuracies_pca}

    # Federated learning for Autoencoder
    global_model_auto = classification_model()
    local_models_auto = [copy.deepcopy(global_model_auto) for _ in range(4)]
    test_losses_auto, test_accuracies_auto = [], []
    for round_idx in range(4):
        local_weights_auto = []
        for client_idx, client_model in enumerate(local_models_auto):
            optimizer = optim.SGD(client_model.parameters(), lr=learning_rate, momentum=momentum)
            for epoch in range(1, n_epochs + 1):
                train(epoch, client_model, auto_client_loaders[client_idx], optimizer, log_interval, [], [])
            client_weights = [param.data.numpy() for param in client_model.parameters()]
            local_weights_auto.append(client_weights)
        global_weights_auto = federated_averaging(local_weights_auto)
        distribute_global_model(global_weights_auto, local_models_auto, single=False)
        distribute_global_model(global_weights_auto, global_model_auto, single=True)
    test(global_model_auto, test_loader_auto, test_losses_auto)
    correct = 0
    with torch.no_grad():
        for data, target in test_loader_auto:
            output = global_model_auto(data)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum().item()
    accuracy = 100. * correct / len(test_loader_auto.dataset)
    test_accuracies_auto.append(accuracy)
    results["autoencoder"][alpha] = {"losses": test_losses_auto, "accuracy": test_accuracies_auto}
# Out:
# Running experiment for alpha = 0.005
#
# Sample 0 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 1 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 2 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 3 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 4 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 5 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 6 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 7 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 8 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 9 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 10 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 11 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 12 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 13 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 14 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 15 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 16 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 17 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 18 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 19 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 20 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 21 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 22 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 23 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 24 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 25 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 26 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 27 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 28 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 29 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 30 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 31 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 32 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 33 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 34 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 35 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 36 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 37 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 38 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 39 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 40 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 41 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 42 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 43 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 44 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 45 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 46 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 47 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 48 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 49 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 50 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 51 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 52 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 53 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 54 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 55 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 56 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 57 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 58 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 59 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 60 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 61 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 62 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 63 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 64 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 65 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 66 shape: torch.Size([1, 28, 28]), Label: 4
# Sample 67 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 68 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 69 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 70 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 71 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 72 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 73 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 74 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 75 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 76 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 77 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 78 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 79 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 80 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 81 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 82 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 83 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 84 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 85 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 86 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 87 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 88 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 89 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 90 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 91 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 92 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 93 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 94 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 95 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 96 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 97 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 98 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 99 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 100 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 101 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 102 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 103 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 104 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 105 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 106 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 107 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 108 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 109 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 110 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 111 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 112 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 113 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 114 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 115 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 116 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 117 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 118 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 119 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 120 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 121 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 122 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 123 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 124 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 125 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 126 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 127 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 128 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 129 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 130 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 131 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 132 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 133 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 134 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 135 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 136 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 137 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 138 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 139 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 140 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 141 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 142 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 143 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 144 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 145 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 146 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 147 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 148 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 149 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 150 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 151 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 152 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 153 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 154 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 155 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 156 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 157 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 158 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 159 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 160 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 161 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 162 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 163 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 164 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 165 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 166 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 167 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 168 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 169 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 170 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 171 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 172 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 173 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 174 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 175 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 176 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 177 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 178 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 179 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 180 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 181 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 182 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 183 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 184 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 185 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 186 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 187 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 188 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 189 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 190 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 191 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 192 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 193 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 194 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 195 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 196 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 197 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 198 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 199 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 200 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 201 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 202 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 203 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 204 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 205 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 206 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 207 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 208 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 209 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 210 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 211 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 212 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 213 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 214 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 215 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 216 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 217 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 218 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 219 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 220 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 221 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 222 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 223 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 224 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 225 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 226 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 227 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 228 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 229 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 230 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 231 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 232 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 233 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 234 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 235 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 236 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 237 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 238 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 239 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 240 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 241 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 242 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 243 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 244 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 245 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 246 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 247 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 248 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 249 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 250 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 251 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 252 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 253 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 254 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 255 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 256 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 257 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 258 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 259 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 260 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 261 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 262 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 263 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 264 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 265 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 266 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 267 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 268 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 269 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 270 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 271 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 272 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 273 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 274 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 275 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 276 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 277 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 278 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 279 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 280 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 281 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 282 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 283 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 284 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 285 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 286 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 287 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 288 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 289 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 290 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 291 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 292 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 293 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 294 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 295 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 296 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 297 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 298 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 299 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 300 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 301 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 302 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 303 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 304 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 305 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 306 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 307 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 308 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 309 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 310 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 311 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 312 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 313 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 314 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 315 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 316 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 317 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 318 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 319 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 320 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 321 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 322 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 323 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 324 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 325 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 326 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 327 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 328 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 329 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 330 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 331 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 332 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 333 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 334 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 335 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 336 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 337 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 338 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 339 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 340 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 341 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 342 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 343 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 344 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 345 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 346 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 347 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 348 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 349 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 350 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 351 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 352 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 353 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 354 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 355 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 356 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 357 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 358 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 359 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 360 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 361 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 362 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 363 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 364 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 365 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 366 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 367 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 368 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 369 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 370 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 371 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 372 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 373 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 374 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 375 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 376 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 377 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 378 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 379 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 380 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 381 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 382 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 383 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 384 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 385 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 386 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 387 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 388 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 389 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 390 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 391 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 392 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 393 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 394 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 395 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 396 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 397 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 398 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 399 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 400 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 401 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 402 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 403 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 404 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 405 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 406 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 407 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 408 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 409 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 410 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 411 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 412 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 413 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 414 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 415 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 416 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 417 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 418 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 419 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 420 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 421 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 422 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 423 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 424 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 425 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 426 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 427 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 428 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 429 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 430 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 431 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 432 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 433 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 434 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 435 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 436 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 437 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 438 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 439 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 440 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 441 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 442 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 443 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 444 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 445 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 446 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 447 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 448 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 449 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 450 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 451 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 452 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 453 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 454 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 455 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 456 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 457 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 458 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 459 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 460 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 461 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 462 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 463 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 464 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 465 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 466 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 467 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 468 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 469 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 470 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 471 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 472 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 473 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 474 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 475 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 476 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 477 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 478 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 479 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 480 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 481 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 482 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 483 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 484 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 485 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 486 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 487 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 488 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 489 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 490 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 491 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 492 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 493 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 494 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 495 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 496 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 497 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 498 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 499 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 500 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 501 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 502 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 503 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 504 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 505 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 506 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 507 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 508 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 509 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 510 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 511 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 512 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 513 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 514 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 515 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 516 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 517 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 518 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 519 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 520 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 521 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 522 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 523 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 524 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 525 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 526 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 527 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 528 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 529 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 530 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 531 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 532 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 533 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 534 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 535 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 536 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 537 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 538 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 539 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 540 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 541 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 542 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 543 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 544 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 545 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 546 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 547 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 548 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 549 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 550 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 551 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 552 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 553 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 554 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 555 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 556 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 557 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 558 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 559 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 560 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 561 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 562 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 563 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 564 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 565 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 566 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 567 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 568 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 569 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 570 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 571 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 572 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 573 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 574 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 575 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 576 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 577 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 578 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 579 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 580 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 581 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 582 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 583 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 584 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 585 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 586 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 587 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 588 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 589 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 590 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 591 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 592 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 593 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 594 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 595 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 596 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 597 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 598 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 599 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 600 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 601 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 602 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 603 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 604 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 605 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 606 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 607 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 608 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 609 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 610 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 611 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 612 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 613 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 614 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 615 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 616 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 617 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 618 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 619 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 620 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 621 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 622 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 623 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 624 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 625 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 626 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 627 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 628 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 629 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 630 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 631 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 632 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 633 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 634 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 635 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 636 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 637 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 638 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 639 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 640 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 641 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 642 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 643 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 644 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 645 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 646 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 647 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 648 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 649 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 650 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 651 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 652 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 653 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 654 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 655 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 656 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 657 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 658 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 659 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 660 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 661 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 662 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 663 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 664 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 665 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 666 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 667 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 668 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 669 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 670 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 671 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 672 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 673 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 674 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 675 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 676 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 677 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 678 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 679 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 680 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 681 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 682 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 683 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 684 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 685 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 686 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 687 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 688 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 689 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 690 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 691 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 692 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 693 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 694 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 695 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 696 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 697 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 698 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 699 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 700 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 701 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 702 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 703 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 704 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 705 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 706 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 707 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 708 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 709 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 710 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 711 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 712 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 713 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 714 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 715 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 716 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 717 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 718 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 719 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 720 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 721 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 722 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 723 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 724 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 725 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 726 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 727 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 728 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 729 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 730 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 731 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 732 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 733 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 734 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 735 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 736 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 737 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 738 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 739 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 740 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 741 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 742 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 743 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 744 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 745 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 746 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 747 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 748 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 749 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 750 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 751 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 752 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 753 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 754 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 755 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 756 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 757 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 758 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 759 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 760 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 761 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 762 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 763 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 764 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 765 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 766 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 767 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 768 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 769 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 770 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 771 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 772 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 773 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 774 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 775 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 776 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 777 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 778 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 779 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 780 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 781 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 782 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 783 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 784 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 785 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 786 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 787 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 788 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 789 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 790 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 791 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 792 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 793 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 794 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 795 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 796 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 797 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 798 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 799 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 800 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 801 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 802 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 803 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 804 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 805 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 806 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 807 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 808 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 809 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 810 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 811 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 812 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 813 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 814 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 815 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 816 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 817 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 818 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 819 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 820 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 821 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 822 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 823 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 824 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 825 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 826 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 827 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 828 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 829 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 830 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 831 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 832 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 833 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 834 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 835 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 836 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 837 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 838 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 839 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 840 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 841 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 842 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 843 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 844 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 845 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 846 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 847 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 848 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 849 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 850 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 851 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 852 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 853 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 854 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 855 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 856 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 857 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 858 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 859 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 860 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 861 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 862 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 863 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 864 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 865 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 866 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 867 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 868 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 869 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 870 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 871 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 872 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 873 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 874 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 875 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 876 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 877 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 878 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 879 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 880 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 881 shape: torch.Size([1, 28, 28]), Label: 5
# Sample 882 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 883 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 884 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 885 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 886 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 887 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 888 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 889 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 890 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 891 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 892 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 893 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 894 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 895 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 896 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 897 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 898 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 899 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 900 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 901 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 902 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 903 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 904 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 905 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 906 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 907 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 908 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 909 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 910 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 911 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 912 shape: torch.Size([1, 28, 28]), Label: 0
# Sample 913 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 914 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 915 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 916 shape: torch.Size([1, 28, 28]), Label: 2
# Sample 917 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 918 shape: torch.Size([1, 28, 28]), Label: 7
# Sample 919 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 920 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 921 shape: torch.Size([1, 28, 28]), Label: 1
# Sample 922 shape: torch.Size([1, 28, 28]), Label: 9
# Sample 923 shape: torch.Size([1, 28, 28]), Label: 7
# ...
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )]
# 1
# Train Epoch: 1 [0/24740 (0%)]	Loss: 0.314981
# Train Epoch: 1 [640/24740 (3%)]	Loss: 0.525486
# Train Epoch: 1 [1280/24740 (5%)]	Loss: 0.373994
# Train Epoch: 1 [1920/24740 (8%)]	Loss: 0.342253
# Train Epoch: 1 [2560/24740 (10%)]	Loss: 0.123786
# Train Epoch: 1 [3200/24740 (13%)]	Loss: 0.349139
# Train Epoch: 1 [3840/24740 (16%)]	Loss: 0.323728
# Train Epoch: 1 [4480/24740 (18%)]	Loss: 0.448692
# Train Epoch: 1 [5120/24740 (21%)]	Loss: 0.359617
# Train Epoch: 1 [5760/24740 (23%)]	Loss: 0.303338
# Train Epoch: 1 [6400/24740 (26%)]	Loss: 0.561172
# Train Epoch: 1 [7040/24740 (28%)]	Loss: 0.242060
# Train Epoch: 1 [7680/24740 (31%)]	Loss: 0.383523
# Train Epoch: 1 [8320/24740 (34%)]	Loss: 0.300548
# Train Epoch: 1 [8960/24740 (36%)]	Loss: 0.342781
# Train Epoch: 1 [9600/24740 (39%)]	Loss: 0.208525
# Train Epoch: 1 [10240/24740 (41%)]	Loss: 0.564236
# Train Epoch: 1 [10880/24740 (44%)]	Loss: 0.338765
# Train Epoch: 1 [11520/24740 (47%)]	Loss: 0.409881
# Train Epoch: 1 [12160/24740 (49%)]	Loss: 0.530967
# Train Epoch: 1 [12800/24740 (52%)]	Loss: 0.499544
# Train Epoch: 1 [13440/24740 (54%)]	Loss: 0.388763
# Train Epoch: 1 [14080/24740 (57%)]	Loss: 0.856286
# Train Epoch: 1 [14720/24740 (59%)]	Loss: 0.307082
# Train Epoch: 1 [15360/24740 (62%)]	Loss: 0.526893
# Train Epoch: 1 [16000/24740 (65%)]	Loss: 0.330552
# Train Epoch: 1 [16640/24740 (67%)]	Loss: 0.151628
# Train Epoch: 1 [17280/24740 (70%)]	Loss: 0.487608
# Train Epoch: 1 [17920/24740 (72%)]	Loss: 0.423997
# Train Epoch: 1 [18560/24740 (75%)]	Loss: 0.256246
# Train Epoch: 1 [19200/24740 (78%)]	Loss: 0.402326
# Train Epoch: 1 [19840/24740 (80%)]	Loss: 0.393759
# Train Epoch: 1 [20480/24740 (83%)]	Loss: 0.310244
# Train Epoch: 1 [21120/24740 (85%)]	Loss: 0.401808
# Train Epoch: 1 [21760/24740 (88%)]	Loss: 0.414531
# Train Epoch: 1 [22400/24740 (90%)]	Loss: 0.495977
# Train Epoch: 1 [23040/24740 (93%)]	Loss: 0.376397
# Train Epoch: 1 [23680/24740 (96%)]	Loss: 0.356858
# Train Epoch: 1 [24320/24740 (98%)]	Loss: 0.628553
# Train Epoch: 2 [0/24740 (0%)]	Loss: 0.423948
# Train Epoch: 2 [640/24740 (3%)]	Loss: 0.371315
# Train Epoch: 2 [1280/24740 (5%)]	Loss: 0.766912
# Train Epoch: 2 [1920/24740 (8%)]	Loss: 0.428262
# Train Epoch: 2 [2560/24740 (10%)]	Loss: 0.381711
# Train Epoch: 2 [3200/24740 (13%)]	Loss: 0.425091
# Train Epoch: 2 [3840/24740 (16%)]	Loss: 0.332291
# Train Epoch: 2 [4480/24740 (18%)]	Loss: 0.453826
# Train Epoch: 2 [5120/24740 (21%)]	Loss: 0.295177
# Train Epoch: 2 [5760/24740 (23%)]	Loss: 1.005988
# Train Epoch: 2 [6400/24740 (26%)]	Loss: 0.405886
# Train Epoch: 2 [7040/24740 (28%)]	Loss: 0.409823
# Train Epoch: 2 [7680/24740 (31%)]	Loss: 0.373903
# Train Epoch: 2 [8320/24740 (34%)]	Loss: 0.210094
# Train Epoch: 2 [8960/24740 (36%)]	Loss: 0.407597
# Train Epoch: 2 [9600/24740 (39%)]	Loss: 0.194834
# Train Epoch: 2 [10240/24740 (41%)]	Loss: 0.318259
# Train Epoch: 2 [10880/24740 (44%)]	Loss: 0.428724
# Train Epoch: 2 [11520/24740 (47%)]	Loss: 0.295850
# Train Epoch: 2 [12160/24740 (49%)]	Loss: 0.387531
# Train Epoch: 2 [12800/24740 (52%)]	Loss: 0.471518
# Train Epoch: 2 [13440/24740 (54%)]	Loss: 0.465827
# Train Epoch: 2 [14080/24740 (57%)]	Loss: 0.381390
# Train Epoch: 2 [14720/24740 (59%)]	Loss: 0.409159
# Train Epoch: 2 [15360/24740 (62%)]	Loss: 0.384612
# Train Epoch: 2 [16000/24740 (65%)]	Loss: 0.506449
# Train Epoch: 2 [16640/24740 (67%)]	Loss: 0.249886
# Train Epoch: 2 [17280/24740 (70%)]	Loss: 0.409553
# Train Epoch: 2 [17920/24740 (72%)]	Loss: 0.149338
# Train Epoch: 2 [18560/24740 (75%)]	Loss: 0.273059
# Train Epoch: 2 [19200/24740 (78%)]	Loss: 0.358800
# Train Epoch: 2 [19840/24740 (80%)]	Loss: 0.599133
# Train Epoch: 2 [20480/24740 (83%)]	Loss: 0.378985
# Train Epoch: 2 [21120/24740 (85%)]	Loss: 0.373953
# Train Epoch: 2 [21760/24740 (88%)]	Loss: 0.304677
# Train Epoch: 2 [22400/24740 (90%)]	Loss: 0.306632
# Train Epoch: 2 [23040/24740 (93%)]	Loss: 0.226991
# Train Epoch: 2 [23680/24740 (96%)]	Loss: 0.341195
# Train Epoch: 2 [24320/24740 (98%)]	Loss: 0.302503
# Train Epoch: 3 [0/24740 (0%)]	Loss: 0.275523
# Train Epoch: 3 [640/24740 (3%)]	Loss: 0.431464
# Train Epoch: 3 [1280/24740 (5%)]	Loss: 0.436167
# Train Epoch: 3 [1920/24740 (8%)]	Loss: 0.271660
# Train Epoch: 3 [2560/24740 (10%)]	Loss: 0.578462
# Train Epoch: 3 [3200/24740 (13%)]	Loss: 0.191940
# Train Epoch: 3 [3840/24740 (16%)]	Loss: 0.229491
# Train Epoch: 3 [4480/24740 (18%)]	Loss: 0.471134
# Train Epoch: 3 [5120/24740 (21%)]	Loss: 0.343196
# Train Epoch: 3 [5760/24740 (23%)]	Loss: 0.446063
# Train Epoch: 3 [6400/24740 (26%)]	Loss: 0.186965
# Train Epoch: 3 [7040/24740 (28%)]	Loss: 0.141552
# Train Epoch: 3 [7680/24740 (31%)]	Loss: 0.513018
# Train Epoch: 3 [8320/24740 (34%)]	Loss: 0.268238
# Train Epoch: 3 [8960/24740 (36%)]	Loss: 0.160676
# Train Epoch: 3 [9600/24740 (39%)]	Loss: 0.279338
# Train Epoch: 3 [10240/24740 (41%)]	Loss: 0.320859
# Train Epoch: 3 [10880/24740 (44%)]	Loss: 0.501544
# Train Epoch: 3 [11520/24740 (47%)]	Loss: 0.371738
# Train Epoch: 3 [12160/24740 (49%)]	Loss: 0.381039
# Train Epoch: 3 [12800/24740 (52%)]	Loss: 0.232272
# Train Epoch: 3 [13440/24740 (54%)]	Loss: 0.243413
# Train Epoch: 3 [14080/24740 (57%)]	Loss: 0.140301
# Train Epoch: 3 [14720/24740 (59%)]	Loss: 0.265617
# Train Epoch: 3 [15360/24740 (62%)]	Loss: 0.302028
# Train Epoch: 3 [16000/24740 (65%)]	Loss: 0.235057
# Train Epoch: 3 [16640/24740 (67%)]	Loss: 0.195899
# Train Epoch: 3 [17280/24740 (70%)]	Loss: 0.396143
# Train Epoch: 3 [17920/24740 (72%)]	Loss: 0.496113
# Train Epoch: 3 [18560/24740 (75%)]	Loss: 0.213651
# Train Epoch: 3 [19200/24740 (78%)]	Loss: 0.254694
# Train Epoch: 3 [19840/24740 (80%)]	Loss: 0.382756
# Train Epoch: 3 [20480/24740 (83%)]	Loss: 0.534046
# Train Epoch: 3 [21120/24740 (85%)]	Loss: 0.349131
# Train Epoch: 3 [21760/24740 (88%)]	Loss: 0.191079
# Train Epoch: 3 [22400/24740 (90%)]	Loss: 0.375622
# Train Epoch: 3 [23040/24740 (93%)]	Loss: 0.300090
# Train Epoch: 3 [23680/24740 (96%)]	Loss: 0.506383
# Train Epoch: 3 [24320/24740 (98%)]	Loss: 0.320905
# Train Epoch: 1 [0/15081 (0%)]	Loss: 0.334699
# Train Epoch: 1 [640/15081 (4%)]	Loss: 0.364931
# Train Epoch: 1 [1280/15081 (8%)]	Loss: 0.447403
# Train Epoch: 1 [1920/15081 (13%)]	Loss: 0.420312
# Train Epoch: 1 [2560/15081 (17%)]	Loss: 0.538648
# Train Epoch: 1 [3200/15081 (21%)]	Loss: 0.420025
# Train Epoch: 1 [3840/15081 (25%)]	Loss: 0.413126
# Train Epoch: 1 [4480/15081 (30%)]	Loss: 0.323040
# Train Epoch: 1 [5120/15081 (34%)]	Loss: 0.264544
# Train Epoch: 1 [5760/15081 (38%)]	Loss: 0.286613
# Train Epoch: 1 [6400/15081 (42%)]	Loss: 0.244052
# Train Epoch: 1 [7040/15081 (47%)]	Loss: 0.298280
# Train Epoch: 1 [7680/15081 (51%)]	Loss: 0.231317
# Train Epoch: 1 [8320/15081 (55%)]	Loss: 0.699921
# Train Epoch: 1 [8960/15081 (59%)]	Loss: 0.311876
# Train Epoch: 1 [9600/15081 (64%)]	Loss: 0.294208
# Train Epoch: 1 [10240/15081 (68%)]	Loss: 0.517103
# Train Epoch: 1 [10880/15081 (72%)]	Loss: 0.412226
# Train Epoch: 1 [11520/15081 (76%)]	Loss: 0.452795
# Train Epoch: 1 [12160/15081 (81%)]	Loss: 0.408861
# Train Epoch: 1 [12800/15081 (85%)]	Loss: 0.324973
# Train Epoch: 1 [13440/15081 (89%)]	Loss: 0.276831
# Train Epoch: 1 [14080/15081 (93%)]	Loss: 0.440343
# Train Epoch: 1 [14720/15081 (97%)]	Loss: 0.461423
# Train Epoch: 2 [0/15081 (0%)]	Loss: 0.552289
# Train Epoch: 2 [640/15081 (4%)]	Loss: 0.334037
# Train Epoch: 2 [1280/15081 (8%)]	Loss: 0.529849
# Train Epoch: 2 [1920/15081 (13%)]	Loss: 0.379041
# Train Epoch: 2 [2560/15081 (17%)]	Loss: 0.423803
# Train Epoch: 2 [3200/15081 (21%)]	Loss: 0.435608
# Train Epoch: 2 [3840/15081 (25%)]	Loss: 0.241973
# Train Epoch: 2 [4480/15081 (30%)]	Loss: 0.464212
# Train Epoch: 2 [5120/15081 (34%)]	Loss: 0.627613
# Train Epoch: 2 [5760/15081 (38%)]	Loss: 0.374181
# Train Epoch: 2 [6400/15081 (42%)]	Loss: 0.352840
# Train Epoch: 2 [7040/15081 (47%)]	Loss: 0.397930
# Train Epoch: 2 [7680/15081 (51%)]	Loss: 0.248288
# Train Epoch: 2 [8320/15081 (55%)]	Loss: 0.326564
# Train Epoch: 2 [8960/15081 (59%)]	Loss: 0.398030
# Train Epoch: 2 [9600/15081 (64%)]	Loss: 0.592727
# Train Epoch: 2 [10240/15081 (68%)]	Loss: 0.608037
# Train Epoch: 2 [10880/15081 (72%)]	Loss: 0.157515
# Train Epoch: 2 [11520/15081 (76%)]	Loss: 0.336105
# Train Epoch: 2 [12160/15081 (81%)]	Loss: 0.567751
# Train Epoch: 2 [12800/15081 (85%)]	Loss: 0.282845
# Train Epoch: 2 [13440/15081 (89%)]	Loss: 0.244904
# Train Epoch: 2 [14080/15081 (93%)]	Loss: 0.271220
# Train Epoch: 2 [14720/15081 (97%)]	Loss: 0.408321
# Train Epoch: 3 [0/15081 (0%)]	Loss: 0.411796
# Train Epoch: 3 [640/15081 (4%)]	Loss: 0.319649
# Train Epoch: 3 [1280/15081 (8%)]	Loss: 0.324320
# Train Epoch: 3 [1920/15081 (13%)]	Loss: 0.308544
# Train Epoch: 3 [2560/15081 (17%)]	Loss: 0.294408
# Train Epoch: 3 [3200/15081 (21%)]	Loss: 0.198941
# Train Epoch: 3 [3840/15081 (25%)]	Loss: 0.167880
# Train Epoch: 3 [4480/15081 (30%)]	Loss: 0.657557
# Train Epoch: 3 [5120/15081 (34%)]	Loss: 0.384073
# Train Epoch: 3 [5760/15081 (38%)]	Loss: 0.410076
# Train Epoch: 3 [6400/15081 (42%)]	Loss: 0.340570
# Train Epoch: 3 [7040/15081 (47%)]	Loss: 0.251831
# Train Epoch: 3 [7680/15081 (51%)]	Loss: 0.344873
# Train Epoch: 3 [8320/15081 (55%)]	Loss: 0.366642
# Train Epoch: 3 [8960/15081 (59%)]	Loss: 0.334755
# Train Epoch: 3 [9600/15081 (64%)]	Loss: 0.462622
# Train Epoch: 3 [10240/15081 (68%)]	Loss: 0.376551
# Train Epoch: 3 [10880/15081 (72%)]	Loss: 0.234743
# Train Epoch: 3 [11520/15081 (76%)]	Loss: 0.286455
# Train Epoch: 3 [12160/15081 (81%)]	Loss: 0.252208
# Train Epoch: 3 [12800/15081 (85%)]	Loss: 0.510922
# Train Epoch: 3 [13440/15081 (89%)]	Loss: 0.294248
# Train Epoch: 3 [14080/15081 (93%)]	Loss: 0.312732
# Train Epoch: 3 [14720/15081 (97%)]	Loss: 0.449774
# Train Epoch: 1 [0/10430 (0%)]	Loss: 0.397709
# Train Epoch: 1 [640/10430 (6%)]	Loss: 0.520762
# Train Epoch: 1 [1280/10430 (12%)]	Loss: 0.243439
# Train Epoch: 1 [1920/10430 (18%)]	Loss: 0.395058
# Train Epoch: 1 [2560/10430 (25%)]	Loss: 0.403000
# Train Epoch: 1 [3200/10430 (31%)]	Loss: 0.121021
# Train Epoch: 1 [3840/10430 (37%)]	Loss: 0.289534
# Train Epoch: 1 [4480/10430 (43%)]	Loss: 0.342292
# Train Epoch: 1 [5120/10430 (49%)]	Loss: 0.358283
# Train Epoch: 1 [5760/10430 (55%)]	Loss: 0.362246
# Train Epoch: 1 [6400/10430 (61%)]	Loss: 0.195573
# Train Epoch: 1 [7040/10430 (67%)]	Loss: 0.192746
# Train Epoch: 1 [7680/10430 (74%)]	Loss: 0.319684
# Train Epoch: 1 [8320/10430 (80%)]	Loss: 0.237902
# Train Epoch: 1 [8960/10430 (86%)]	Loss: 0.277416
# Train Epoch: 1 [9600/10430 (92%)]	Loss: 0.224978
# Train Epoch: 1 [10240/10430 (98%)]	Loss: 0.240226
# Train Epoch: 2 [0/10430 (0%)]	Loss: 0.243624
# Train Epoch: 2 [640/10430 (6%)]	Loss: 0.238798
# Train Epoch: 2 [1280/10430 (12%)]	Loss: 0.328174
# Train Epoch: 2 [1920/10430 (18%)]	Loss: 0.264250
# Train Epoch: 2 [2560/10430 (25%)]	Loss: 0.242131
# Train Epoch: 2 [3200/10430 (31%)]	Loss: 0.469164
# Train Epoch: 2 [3840/10430 (37%)]	Loss: 0.244530
# Train Epoch: 2 [4480/10430 (43%)]	Loss: 0.170135
# Train Epoch: 2 [5120/10430 (49%)]	Loss: 0.188711
# Train Epoch: 2 [5760/10430 (55%)]	Loss: 0.325104
# Train Epoch: 2 [6400/10430 (61%)]	Loss: 0.144978
# Train Epoch: 2 [7040/10430 (67%)]	Loss: 0.290904
# Train Epoch: 2 [7680/10430 (74%)]	Loss: 0.209008
# Train Epoch: 2 [8320/10430 (80%)]	Loss: 0.161402
# Train Epoch: 2 [8960/10430 (86%)]	Loss: 0.289801
# Train Epoch: 2 [9600/10430 (92%)]	Loss: 0.134661
# Train Epoch: 2 [10240/10430 (98%)]	Loss: 0.132032
# Train Epoch: 3 [0/10430 (0%)]	Loss: 0.216682
# Train Epoch: 3 [640/10430 (6%)]	Loss: 0.239609
# Train Epoch: 3 [1280/10430 (12%)]	Loss: 0.199906
# Train Epoch: 3 [1920/10430 (18%)]	Loss: 0.185154
# Train Epoch: 3 [2560/10430 (25%)]	Loss: 0.229187
# Train Epoch: 3 [3200/10430 (31%)]	Loss: 0.197185
# Train Epoch: 3 [3840/10430 (37%)]	Loss: 0.253692
# Train Epoch: 3 [4480/10430 (43%)]	Loss: 0.271667
# Train Epoch: 3 [5120/10430 (49%)]	Loss: 0.309697
# Train Epoch: 3 [5760/10430 (55%)]	Loss: 0.209031
# Train Epoch: 3 [6400/10430 (61%)]	Loss: 0.288016
# Train Epoch: 3 [7040/10430 (67%)]	Loss: 0.241485
# Train Epoch: 3 [7680/10430 (74%)]	Loss: 0.264874
# Train Epoch: 3 [8320/10430 (80%)]	Loss: 0.209003
# Train Epoch: 3 [8960/10430 (86%)]	Loss: 0.178730
# Train Epoch: 3 [9600/10430 (92%)]	Loss: 0.311657
# Train Epoch: 3 [10240/10430 (98%)]	Loss: 0.280049
# Train Epoch: 1 [0/9749 (0%)]	Loss: 0.495981
# Train Epoch: 1 [640/9749 (7%)]	Loss: 0.506671
# Train Epoch: 1 [1280/9749 (13%)]	Loss: 0.538543
# Train Epoch: 1 [1920/9749 (20%)]	Loss: 0.630866
# Train Epoch: 1 [2560/9749 (26%)]	Loss: 0.543692
# Train Epoch: 1 [3200/9749 (33%)]	Loss: 0.482073
# Train Epoch: 1 [3840/9749 (39%)]	Loss: 0.367865
# Train Epoch: 1 [4480/9749 (46%)]	Loss: 0.341689
# Train Epoch: 1 [5120/9749 (52%)]	Loss: 0.270731
# Train Epoch: 1 [5760/9749 (59%)]	Loss: 0.241458
# Train Epoch: 1 [6400/9749 (65%)]	Loss: 0.349017
# Train Epoch: 1 [7040/9749 (72%)]	Loss: 0.272956
# Train Epoch: 1 [7680/9749 (78%)]	Loss: 0.350206
# Train Epoch: 1 [8320/9749 (85%)]	Loss: 0.328457
# Train Epoch: 1 [8960/9749 (92%)]	Loss: 0.375625
# Train Epoch: 1 [9600/9749 (98%)]	Loss: 0.436974
# Train Epoch: 2 [0/9749 (0%)]	Loss: 0.428178
# Train Epoch: 2 [640/9749 (7%)]	Loss: 0.314237
# Train Epoch: 2 [1280/9749 (13%)]	Loss: 0.286735
# Train Epoch: 2 [1920/9749 (20%)]	Loss: 0.468212
# Train Epoch: 2 [2560/9749 (26%)]	Loss: 0.318604
# Train Epoch: 2 [3200/9749 (33%)]	Loss: 0.336178
# Train Epoch: 2 [3840/9749 (39%)]	Loss: 0.326920
# Train Epoch: 2 [4480/9749 (46%)]	Loss: 0.403987
# Train Epoch: 2 [5120/9749 (52%)]	Loss: 0.416931
# Train Epoch: 2 [5760/9749 (59%)]	Loss: 0.331513
# Train Epoch: 2 [6400/9749 (65%)]	Loss: 0.399262
# Train Epoch: 2 [7040/9749 (72%)]	Loss: 0.425093
# Train Epoch: 2 [7680/9749 (78%)]	Loss: 0.365203
# Train Epoch: 2 [8320/9749 (85%)]	Loss: 0.410595
# Train Epoch: 2 [8960/9749 (92%)]	Loss: 0.488172
# Train Epoch: 2 [9600/9749 (98%)]	Loss: 0.572354
# Train Epoch: 3 [0/9749 (0%)]	Loss: 0.360721
# Train Epoch: 3 [640/9749 (7%)]	Loss: 0.212636
# Train Epoch: 3 [1280/9749 (13%)]	Loss: 0.517494
# Train Epoch: 3 [1920/9749 (20%)]	Loss: 0.457955
# Train Epoch: 3 [2560/9749 (26%)]	Loss: 0.446664
# Train Epoch: 3 [3200/9749 (33%)]	Loss: 0.567239
# Train Epoch: 3 [3840/9749 (39%)]	Loss: 0.330308
# Train Epoch: 3 [4480/9749 (46%)]	Loss: 0.326715
# Train Epoch: 3 [5120/9749 (52%)]	Loss: 0.499325
# Train Epoch: 3 [5760/9749 (59%)]	Loss: 0.476444
# Train Epoch: 3 [6400/9749 (65%)]	Loss: 0.254339
# Train Epoch: 3 [7040/9749 (72%)]	Loss: 0.318948
# Train Epoch: 3 [7680/9749 (78%)]	Loss: 0.295943
# Train Epoch: 3 [8320/9749 (85%)]	Loss: 0.449676
# Train Epoch: 3 [8960/9749 (92%)]	Loss: 0.362517
# Train Epoch: 3 [9600/9749 (98%)]	Loss: 0.215694
# local_models in the distribute function [classification_model(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# ), classification_model(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# ), classification_model(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# ), classification_model(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )]
# 4
# local_models in the distribute function [classification_model(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )]
# 1
#
# Test set: Avg. loss: 0.2382, Accuracy: 9483/10000 (95%)

# %%
#Todo??
testSetAvgLosses = [1.0049, 0.6043, 0.3336, 0.8381, 0.7255, ....]
testSetAvgAccuracy = [92, 83, 90, 91, 81, ....]

# %%
for method, method_results in results.items():
    print(f"\nResults for {method}:")
    for alpha, metrics in method_results.items():
        print(f"  Alpha {alpha}: Losses = {metrics['losses']}, Accuracy = {metrics['accuracy']}")
# Out:
# Results for classic:
#   Alpha 0.005: Losses = [0.49943628845214844], Accuracy = [84.72]
#   Alpha 0.05: Losses = [0.3336496337890625], Accuracy = [89.66]
#   Alpha 0.1: Losses = [0.16874794006347657], Accuracy = [94.83]
#   Alpha 0.3: Losses = [0.14123596801757812], Accuracy = [96.0]
#   Alpha 0.5: Losses = [0.11874948120117187], Accuracy = [96.15]
#   Alpha 0.7: Losses = [0.10253834075927734], Accuracy = [96.56]
#   Alpha 0.9: Losses = [0.10070584869384766], Accuracy = [97.05]
#   Alpha 1: Losses = [0.09446857681274413], Accuracy = [96.94]
#
# Results for pca:
#   Alpha 0.005: Losses = [1.0049324462890625], Accuracy = [92.18]
#   Alpha 0.05: Losses = [0.8381243835449219], Accuracy = [91.32]
#   Alpha 0.1: Losses = [0.6158310668945313], Accuracy = [95.93]
#   Alpha 0.3: Losses = [0.4067485534667969], Accuracy = [97.47]
#   Alpha 0.5: Losses = [0.4018714111328125], Accuracy = [97.05]
#   Alpha 0.7: Losses = [0.37564517517089846], Accuracy = [97.7]
#   Alpha 0.9: Losses = [0.3578442749023438], Accuracy = [97.49]
#   Alpha 1: Losses = [0.37470167541503907], Accuracy = [97.52]
#
# Results for autoencoder:
#   Alpha 0.005: Losses = [0.6043230529785156], Accuracy = [83.15]
#   Alpha 0.05: Losses = [0.7254594055175781], Accuracy = [80.62]
#   Alpha 0.1: Losses = [0.34273814544677733], Accuracy = [91.64]
#   Alpha 0.3: Losses = [0.27317487335205076], Accuracy = [93.47]
#   Alpha 0.5: Losses = [0.27595465545654296], Accuracy = [94.16]
#   Alpha 0.7: Losses = [0.25261497497558594], Accuracy = [94.46]
#   Alpha 0.9: Losses = [0.2683180389404297], Accuracy = [94.39]
#   Alpha 1: Losses = [0.2382182357788086], Accuracy = [94.83]

# %%
import matplotlib.pyplot as plt

alpha_values = list(results["classic"].keys())
methods = list(results.keys())
losses = {method: [results[method][alpha]["losses"] for alpha in alpha_values] for method in methods}
accuracies = {method: [results[method][alpha]["accuracy"] for alpha in alpha_values] for method in methods}

plt.figure(figsize=(12, 6))
for method in methods:
    avg_losses = [sum(loss) / len(loss) for loss in losses[method]]  
    #print(avg_losses)
    plt.plot(alpha_values, avg_losses, marker='o', label=method)

plt.xlabel('Alpha Values')
plt.ylabel('Average Test Loss')
plt.title('Federated Learning Test Loss Across Alpha Values')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
for method in methods:
    avg_accuracies = [sum(acc) / len(acc) for acc in accuracies[method]]  
    #print(avg_accuracies)
    plt.plot(alpha_values, avg_accuracies, marker='o', label=method)
plt.xlabel('Alpha Values')
plt.ylabel('Accuracy (%)')
plt.title('Federated Learning Test Accuracy Across Alpha Values')
plt.legend()
plt.grid(True)
plt.show()
